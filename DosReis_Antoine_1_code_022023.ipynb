# %% [markdown]
# # Détectez des faux billets avec Python

# %% [markdown]
# ![logo_ONCFM.png](attachment:logo_ONCFM.png)

# %% [markdown]
# <h1>Table des matières<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Contexte-du-projet" data-toc-modified-id="Contexte-du-projet-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Contexte du projet</a></span></li><li><span><a href="#Importation-des-librairies" data-toc-modified-id="Importation-des-librairies-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Importation des librairies</a></span></li><li><span><a href="#Importation-des-données" data-toc-modified-id="Importation-des-données-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Importation des données</a></span></li></ul></li><li><span><a href="#Analyse-descriptive-des-données" data-toc-modified-id="Analyse-descriptive-des-données-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Analyse descriptive des données</a></span><ul class="toc-item"><li><span><a href="#Structure-des-données" data-toc-modified-id="Structure-des-données-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Structure des données</a></span></li><li><span><a href="#Distribution-des-variables" data-toc-modified-id="Distribution-des-variables-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Distribution des variables</a></span></li><li><span><a href="#Heatmap-des-corrélations" data-toc-modified-id="Heatmap-des-corrélations-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Heatmap des corrélations</a></span></li><li><span><a href="#Divers" data-toc-modified-id="Divers-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Divers</a></span></li></ul></li><li><span><a href="#Régression-linéaire" data-toc-modified-id="Régression-linéaire-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Régression linéaire</a></span><ul class="toc-item"><li><span><a href="#Initialisation-du-modèle" data-toc-modified-id="Initialisation-du-modèle-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Initialisation du modèle</a></span></li><li><span><a href="#Suppression-des-variables-non-significatives" data-toc-modified-id="Suppression-des-variables-non-significatives-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Suppression des variables non significatives</a></span></li><li><span><a href="#Analyse-des-données-atypiques-et-influentes" data-toc-modified-id="Analyse-des-données-atypiques-et-influentes-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Analyse des données atypiques et influentes</a></span><ul class="toc-item"><li><span><a href="#Calcul-des-leviers" data-toc-modified-id="Calcul-des-leviers-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Calcul des leviers</a></span></li><li><span><a href="#Calcul-des-résidus-studentisés" data-toc-modified-id="Calcul-des-résidus-studentisés-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Calcul des résidus studentisés</a></span></li><li><span><a href="#Distance-de-Cook" data-toc-modified-id="Distance-de-Cook-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Distance de Cook</a></span></li><li><span><a href="#Suppression-des-valeurs-atypiques-et-influentes" data-toc-modified-id="Suppression-des-valeurs-atypiques-et-influentes-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Suppression des valeurs atypiques et influentes</a></span></li></ul></li><li><span><a href="#Ajustement-du-modèle" data-toc-modified-id="Ajustement-du-modèle-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Ajustement du modèle</a></span><ul class="toc-item"><li><span><a href="#Transformation-logarithmique-de-la-variable-cible" data-toc-modified-id="Transformation-logarithmique-de-la-variable-cible-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Transformation logarithmique de la variable cible</a></span></li></ul></li><li><span><a href="#Validation-du-modèle" data-toc-modified-id="Validation-du-modèle-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Validation du modèle</a></span><ul class="toc-item"><li><span><a href="#Hypothèse-1:-Relation-linéaire-entre-la-variable-dépendantes-et-les-variables-indépendantes" data-toc-modified-id="Hypothèse-1:-Relation-linéaire-entre-la-variable-dépendantes-et-les-variables-indépendantes-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Hypothèse 1: Relation linéaire entre la variable dépendantes et les variables indépendantes</a></span></li><li><span><a href="#Hypothèse--2:-Normalité-des-résidus" data-toc-modified-id="Hypothèse--2:-Normalité-des-résidus-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Hypothèse  2: Normalité des résidus</a></span></li><li><span><a href="#Hypothèse-3:-Pas-de-multicolinéarité-entre-les-variables-indépendantes" data-toc-modified-id="Hypothèse-3:-Pas-de-multicolinéarité-entre-les-variables-indépendantes-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Hypothèse 3: Pas de multicolinéarité entre les variables indépendantes</a></span></li><li><span><a href="#Hypothèse-4:-Pas-d'autocorrélation-des-résidus" data-toc-modified-id="Hypothèse-4:-Pas-d'autocorrélation-des-résidus-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Hypothèse 4: Pas d'autocorrélation des résidus</a></span></li><li><span><a href="#Hypothèse-5-:-Homoscédasticité-des-résidus" data-toc-modified-id="Hypothèse-5-:-Homoscédasticité-des-résidus-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>Hypothèse 5 : Homoscédasticité des résidus</a></span></li></ul></li><li><span><a href="#Evaluation-du-Test-set" data-toc-modified-id="Evaluation-du-Test-set-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Evaluation du Test set</a></span></li><li><span><a href="#Prédictions-des-données-manquantes-à-partir-du-modèle" data-toc-modified-id="Prédictions-des-données-manquantes-à-partir-du-modèle-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Prédictions des données manquantes à partir du modèle</a></span></li></ul></li><li><span><a href="#Régression-logistique" data-toc-modified-id="Régression-logistique-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Régression logistique</a></span><ul class="toc-item"><li><span><a href="#Initialisation-du-modèle" data-toc-modified-id="Initialisation-du-modèle-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Initialisation du modèle</a></span></li><li><span><a href="#Validation-du-modèle" data-toc-modified-id="Validation-du-modèle-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Validation du modèle</a></span><ul class="toc-item"><li><span><a href="#Hypothèse-1:-La-variable-de-réponse-est-binaire" data-toc-modified-id="Hypothèse-1:-La-variable-de-réponse-est-binaire-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Hypothèse 1: La variable de réponse est binaire</a></span></li><li><span><a href="#Hypothèse-2:-Les-observations-sont-indépendantes" data-toc-modified-id="Hypothèse-2:-Les-observations-sont-indépendantes-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Hypothèse 2: Les observations sont indépendantes</a></span></li><li><span><a href="#Hypothèse--3:-Pas-de-multicolinéarité-entre-les-variables-explicatives" data-toc-modified-id="Hypothèse--3:-Pas-de-multicolinéarité-entre-les-variables-explicatives-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Hypothèse  3: Pas de multicolinéarité entre les variables explicatives</a></span></li><li><span><a href="#Hypothèse-4:-Pas-de-valeurs-extrêmes-aberrantes" data-toc-modified-id="Hypothèse-4:-Pas-de-valeurs-extrêmes-aberrantes-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Hypothèse 4: Pas de valeurs extrêmes aberrantes</a></span></li><li><span><a href="#Hypothèse-5:-Relation-linéaire-entre-les-variables-explicatives-et-le-logit-de-la-variable-de-réponse" data-toc-modified-id="Hypothèse-5:-Relation-linéaire-entre-les-variables-explicatives-et-le-logit-de-la-variable-de-réponse-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Hypothèse 5: Relation linéaire entre les variables explicatives et le logit de la variable de réponse</a></span></li><li><span><a href="#Hypothèse-6:-La-taille-de-l'échantillon-est-suffisament-grande" data-toc-modified-id="Hypothèse-6:-La-taille-de-l'échantillon-est-suffisament-grande-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Hypothèse 6: La taille de l'échantillon est suffisament grande</a></span></li></ul></li><li><span><a href="#Evaluation-du-modèle-sur-le-Test-Set" data-toc-modified-id="Evaluation-du-modèle-sur-le-Test-Set-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Evaluation du modèle sur le Test Set</a></span></li></ul></li><li><span><a href="#Prédictions-via-k-means" data-toc-modified-id="Prédictions-via-k-means-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Prédictions via k-means</a></span><ul class="toc-item"><li><span><a href="#k-means" data-toc-modified-id="k-means-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>k-means</a></span></li><li><span><a href="#Evaluation-du-modèle-k-means" data-toc-modified-id="Evaluation-du-modèle-k-means-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Evaluation du modèle k-means</a></span></li><li><span><a href="#ACP-pour-projection-des-individus" data-toc-modified-id="ACP-pour-projection-des-individus-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>ACP pour projection des individus</a></span></li></ul></li><li><span><a href="#Application-des-modèles-sur-données-inconnues" data-toc-modified-id="Application-des-modèles-sur-données-inconnues-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Application des modèles sur données inconnues</a></span><ul class="toc-item"><li><span><a href="#Par-régression-logistique" data-toc-modified-id="Par-régression-logistique-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Par régression logistique</a></span></li><li><span><a href="#Par-K-Means" data-toc-modified-id="Par-K-Means-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Par K-Means</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Contexte du projet

# %% [markdown]
# L’Organisation nationale de lutte contre le faux-monnayage, ou ONCFM, est une organisation publique ayant pour objectif de mettre en place des méthodes d’identification des contrefaçons des billets en euros. Dans le cadre de cette lutte, nous souhaitons mettre en place un algorithme qui soit capable de différencier automatiquement les vrais des faux billets.
#
# **Objectifs:**
#
# Lorsqu’un billet arrive, nous avons une machine qui consigne l’ensemble de ses caractéristiques géométriques. Au travers de nos années de lutte, nous avons observé des différences de dimensions entre les vrais et les faux billets. Ces différences sont difficilement notables à l’œil nu, mais une machine devrait sans problème arriver à les différencier.
#
# Ainsi, il faudrait construire un algorithme qui, à partir des caractéristiques géométriques d’un billet, serait capable de définir si ce dernier est un vrai ou un faux billet.

# %% [markdown]
# ### Importation des librairies

# %%
#Chargement des différentes librairies

#Traitement des données
import numpy as np
import pandas as pd

#Visualisation de données
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

#Analyse statistique
import scipy
from scipy import stats as st
from scipy.stats import shapiro, t

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.diagnostic import het_breuschpagan
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod import families
from statsmodels.stats.stattools import durbin_watson

#Machine Learning
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, confusion_matrix, roc_curve, roc_auc_score
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA


#Autres
from tabulate import tabulate
import warnings
warnings.filterwarnings('ignore')

#Versions des librairies
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Seaborn version:", sns.__version__)
print("SciPy version:", scipy.__version__)
print("Scikit-Learn version:",sk.__version__)
print("Statsmodels version:", sm.__version__)

#Thème pour Seaborn
sns.set_theme(style="darkgrid", palette="pastel")

#Chargement d'un functions.py avec mes fonctions créées
from functions import *
# Out:
# NumPy version: 1.20.3
# Pandas version: 1.3.4
# Matplotlib version: 3.4.3
# Seaborn version: 0.11.2
# SciPy version: 1.7.1
# Scikit-Learn version: 0.24.2
# Statsmodels version: 0.12.2

# %% [markdown]
# **Version des librairies utilisées:**
#
# - NumPy version: 1.20.3
# - Pandas version: 1.3.4
# - Matplotlib version: 3.4.3
# - Seaborn version: 0.11.2
# - SciPy version: 1.7.1
# - Scikit-Learn version: 0.24.2
# - Statsmodels version: 0.12.2

# %% [markdown]
# ### Importation des données

# %%
df = pd.read_csv("Data/billets.csv", sep=";")
df
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %% [markdown]
# Nous disposons actuellement de six informations géométriques sur un billet :
#
# - length : la longueur du billet (en mm) ;
# - height_left : la hauteur du billet (mesurée sur le côté gauche, en mm) ;
# - height_right : la hauteur du billet (mesurée sur le côté droit, en mm) ;
# - margin_up : la marge entre le bord supérieur du billet et l'image de celui-ci (en mm) ;
# - margin_low : la marge entre le bord inférieur du billet et l'image de celui-ci (en mm) ;
# - diagonal : la diagonale du billet (en mm).
#
# Une colonne "is_genuine" a été ajoutée pour vous préciser la véritable nature du billet.

# %% [markdown]
# ## Analyse descriptive des données

# %% [markdown]
# ### Structure des données

# %%
data_analyse(df)
# Out:
# Structure du dataframe:
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB
# None
#
#
# Vérification des valeurs uniques:
# --------------------
# is_genuine        2
# diagonal        159
# height_left     155
# height_right    170
# margin_low      285
# margin_up       123
# length          336
# dtype: int64
#
#
# Valeurs manquantes:
# --------------------
# is_genuine       0
# diagonal         0
# height_left      0
# height_right     0
# ...

# %%
# Affichage des valeurs nulles
df[df.isnull().any(axis=1)]
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72          True    171.94       103.89        103.45         NaN       3.25
# 99          True    171.93       104.07        104.18         NaN       3.14
# 151         True    172.07       103.80        104.38         NaN       3.02
# 197         True    171.45       103.66        103.80         NaN       3.62
# 241         True    171.83       104.14        104.06         NaN       3.02
# 251         True    171.80       103.26        102.82         NaN       2.95
# 284         True    171.92       103.83        103.76         NaN       3.23
# 334         True    171.85       103.70        103.96         NaN       3.00
# 410         True    172.56       103.72        103.51         NaN       3.12
# 413         True    172.30       103.66        103.50         NaN       3.16
# 445         True    172.34       104.42        103.22         NaN       3.01
# ...

# %% [markdown]
# ### Distribution des variables

# %%
#Visualisation de la distribution des variables
sns.pairplot(df, hue='is_genuine')

# %%
#On regroupe les variables numériques dans une liste
cols = ['diagonal', 'height_left', 'height_right', 'margin_low',
       'margin_up', 'length']

# Boucle pour tracer la distribution de chaque variable
plt.figure(figsize=(20, 20))

for i, column in enumerate(cols):
    plt.subplot(3, 3, i + 1)
    sns.histplot(df[column], kde=True)
    plt.title(column, fontsize=14)

plt.show()

# %% [markdown]
# ### Heatmap des corrélations

# %%
#Heatmap de corrélation des variables
sns.heatmap(df.corr(),annot=True, fmt=".2f")
plt.title('Heatmap de la corrélation des variables')
plt.show()

# %% [markdown]
# ### Divers

# %%
# Graphique sur la répartion du nombre de vrais / faux billets
counts = df['is_genuine'].value_counts()

plt.figure(figsize=(16,5))
plt.pie(counts, labels=['True', 'False'], startangle=90, autopct=make_autopct(counts))
plt.title('Nombre de vrais / faux billets', fontsize=16, fontweight="bold")
plt.show()

# %%
# Boucle pour tracer un boxplot pour chaque variable en fonction de la validité ou non du billet
plt.figure(figsize=(20, 20))

for i, column in enumerate(cols):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x='is_genuine', y=column, data=df)
    plt.title(f'"{column}" en fonction de "is_genuine"')
    plt.xlabel('is_genuine')
    plt.ylabel(column)

plt.show()

# %%
#Aggrégation par la moyenne en fonction de la validité
df.groupby('is_genuine').mean()
# Out:
#              diagonal  height_left  height_right  margin_low  margin_up  \
# is_genuine
# False       171.90116    104.19034     104.14362    5.215935    3.35016
# True        171.98708    103.94913     103.80865    4.116097    3.05213
#
#                length
# is_genuine
# False       111.63064
# True        113.20243

# %% [markdown]
# **En conclusion:**
#
# - 1500 lignes et 7 colonnes
# - Les types de données sont correctes
# - Pas de valeurs aberrantes
# - 37 valeurs manquantes dans la colonne 'margin_low' que nous allons devoir traiter
# - Au niveau de la répartition des billets: 2/3 sont vrais, 1/3 sont faux
# - Il semble y avoir des corrélations entre certaines variables
# - Les variables "length" et "margin_low" ne semblent pas suivre une distribution normale
#     - Par ailleurs, ce sont les variables qui semblent avoir le plus de différence entre les vrais et les faux billets

# %% [markdown]
# ## Régression linéaire

# %% [markdown]
# Le nettoyage va ici consister à travailler sur les 37 valeurs manquantes de la colonne "margin_low".
# Pour cela, nous allons effectuer une régression linéaire multiple en utilisant la méthode des Moindres Carrés Ordinaires (OLS).

# %% [markdown]
# ### Initialisation du modèle

# %% [markdown]
# Avant de commencer, nous devons créer deux nouveaux DataFrames :
#
# - "df_notnull" contenant toutes les lignes avec des valeurs non nulles pour la colonne "margin_low"
# - "df_null" contenant toutes les lignes avec des valeurs nulles pour cette même colonne

# %%
#Division des données en deux parties : une partie avec des valeurs non manquantes pour 'margin_low'et une partie avec des valeurs manquantes
df_notnull = df.dropna(subset=['margin_low'])
df_null = df[df['margin_low'].isnull()]

# %% [markdown]
# Ensuite, nous devons procéder à la création d'un ensemble d'entraînement (training set) et d'un ensemble de test (test set). La séparation en training set / test set nous permettra d'évaluer les performances de notre modèle sur des données non vues (pour vérifier si le modèle généralise bien à de nouvelles données).
#
# Pour cela la méthode `train_test_split`  de la bibliothèque ` Scikit-learn` .

# %%
#Création d'un training set et d'un test set pour les valeurs non manquantes
X = df_notnull.drop('margin_low', axis=1)
y = df_notnull['margin_low']

X_train_reg_lin, X_test_reg_lin, y_train_reg_lin, y_test_reg_lin = train_test_split(X, y, test_size=0.3, random_state=42)

print("Taille du training set:", X_train_reg_lin.shape[0])
print("Taille du test set:", X_test_reg_lin.shape[0])
# Out:
# Taille du training set: 1024
# Taille du test set: 439

# %% [markdown]
# Nous pouvons maintent créér un modèle de régression linéaire à l'aide de la méthode des moindres carrés ordinaires (OLS) en utilisant la bibliothèque ` StatsModels` .

# %%
#Création d'un objet OLS et ajustement du modèle sur le training set
model_reg_lin = ols("margin_low ~ is_genuine+diagonal+height_left+height_right+margin_up+length", data=X_train_reg_lin.join(y_train_reg_lin)).fit()
#Affichage des résultats de la régression
print(model_reg_lin.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.604
# Method:                 Least Squares   F-statistic:                     261.4
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):          4.21e-202
# Time:                        16:54:38   Log-Likelihood:                -561.95
# No. Observations:                1024   AIC:                             1138.
# Df Residuals:                    1017   BIC:                             1172.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.8437     10.311      0.179      0.858     -18.389      22.076
# ...

# %% [markdown]
# Le modèle montre une valeur élevée du R² (0,607), ce qui indique que les variables explicatives fournies expliquent environ 60% de la variation de la variable cible 'margin_low'. Cela peut être considéré comme un bon ajustement du modèle.
#
# Cependant, les résultats montrent que certaines variables explicatives ne sont pas significatives pour prédire la variable cible.
#
# En effet, les variables 'diagonal', 'height_left', 'height_right', 'length' ne sont pas significatives avec des valeurs de p> 0,05.
#
# Nous devons donc ajuster notre modèle en supprimant les variables non significatives.

# %% [markdown]
# ### Suppression des variables non significatives

# %% [markdown]
# Nous devons sélectionner les variables les plus importantes pour la prédiction de la variable cible.
# Dans notre cas, les variables "is_genuine" et "margin_up" doivent être utilisées pour la prédiction de "margin_low".
#
# Nous créons donc un nouveau training set et test set avec seulement ces deux variables.

# %%
#Création d'un training set et d'un test set pour les valeurs non manquantes
X = df_notnull[['is_genuine', 'margin_up']]
y = df_notnull['margin_low']

X_train_reg_lin, X_test_reg_lin, y_train_reg_lin, y_test_reg_lin = train_test_split(X, y, test_size=0.3, random_state=42)

print("Taille du training set:", X_train_reg_lin.shape[0])
print("Taille du test set:", X_test_reg_lin.shape[0])
# Out:
# Taille du training set: 1024
# Taille du test set: 439

# %%
#Création d'un objet OLS et ajustement du modèle sur le training set
model_reg_lin = ols("margin_low ~ is_genuine+margin_up", data=X_train_reg_lin.join(y_train_reg_lin)).fit()
#Affichage des résultats de la régression
print(model_reg_lin.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     786.0
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):          2.26e-207
# Time:                        16:54:38   Log-Likelihood:                -562.46
# No. Observations:                1024   AIC:                             1131.
# Df Residuals:                    1021   BIC:                             1146.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.8727      0.246     23.911      0.000       5.391       6.355
# ...

# %% [markdown]
# Les résultats montrent que le modèle linéaire avec les variables 'is_genuine' et 'margin_up' explique 60,6% de la variation de la variable dépendante 'margin_low.'
#
# La variable 'is_genuine' a un effet négatif significatif sur la variable dépendante, ce qui signifie que les billets authentiques ont une marge plus faible que les billets contrefaits. La variable 'margin_up' a également un effet négatif significatif.

# %% [markdown]
# ### Analyse des données atypiques et influentes

# %% [markdown]
# Après avoir estimé notre modèle de régression linéaire, nous devons maintenant l'analyser.
#
# Commençons par l'atypicité et l'influence éventuelle de certaines données.
# On pourra retirer les données atypiques et influentes afin d'améliorer notre modèle.

# %% [markdown]
# #### Calcul des leviers

# %% [markdown]
# Nous allons ici réaliser les tests à un niveau $\alpha=5$% .
#
# Récupérons $n$, le nombre d'individus de l'échantillon d'entrainement, et $p$, le nombre de variables.

# %%
# Définition des paramètres
alpha = 0.05
n = X_train_reg_lin.shape[0]
p = 3

# %%
# Calcul des leviers et définition du seuil
X_train_reg_lin["obs"] = np.arange(1, n+1)
X_train_reg_lin['levier'] = model_reg_lin.get_influence().hat_matrix_diag

seuil_levier = 2*p/n

# %%
# Représentation graphique
plt.figure(figsize=(10,6))
plt.bar(X_train_reg_lin['obs'], X_train_reg_lin['levier'])
plt.xlabel('Observation')
plt.ylabel('Leviers')
plt.plot([0, 1025], [seuil_levier, seuil_levier], color='r')
plt.show()

# %%
# Identifier les leviers supérieurs au seuil
leviers_influents = X_train_reg_lin[X_train_reg_lin['levier'] > seuil_levier].index
print(leviers_influents.shape[0], "leviers supérieurs au seuil.")
print(round(leviers_influents.shape[0] / X_train_reg_lin.shape[0] * 100,2),"% du training set.")
# Out:
# 51 leviers supérieurs au seuil.
# 4.98 % du training set.

# %% [markdown]
# #### Calcul des résidus studentisés

# %%
# Calcul des résidus studentisés et définition du seuil
X_train_reg_lin['rstudent'] = model_reg_lin.get_influence().resid_studentized_internal
seuil_rstudent = t.ppf(1-alpha/2,n-p-1)

# %%
# Représentation graphique
plt.figure(figsize=(10,6))
plt.bar(X_train_reg_lin['obs'], X_train_reg_lin['rstudent'])
plt.xlabel('Observation')
plt.ylabel('Résidus studentisés')
plt.plot([0, 1025], [seuil_rstudent, seuil_rstudent], color='r')
plt.plot([0, 1025], [-seuil_rstudent, -seuil_rstudent], color='r')
plt.show()

# %%
# Identifier les résidus studentisés supérieurs au seuil
rstudents_influents = X_train_reg_lin[np.abs(X_train_reg_lin['rstudent']) > seuil_rstudent].index
print(rstudents_influents.shape[0], "résidus studentisés supérieurs au seuil.")
print(round(rstudents_influents.shape[0] / X_train_reg_lin.shape[0] * 100,2),"% du training set.")
# Out:
# 60 résidus studentisés supérieurs au seuil.
# 5.86 % du training set.

# %% [markdown]
# #### Distance de Cook

# %%
# Calcul des distances de Cook et définition du seuil
influence = model_reg_lin.get_influence().summary_frame()

X_train_reg_lin['dcooks'] = influence['cooks_d']
seuil_dcook = 4/(n-p)

# %%
# Représentation graphique
plt.figure(figsize=(10,6))
plt.bar(X_train_reg_lin['obs'], X_train_reg_lin['dcooks'])
plt.xlabel('Observation')
plt.ylabel('Leviers')
plt.plot([0, 1025], [seuil_dcook, seuil_dcook], color='r')
plt.show()

# %%
# Identifier les observations influentes
dcooks_influents = X_train_reg_lin[X_train_reg_lin['dcooks'] > seuil_dcook].index
print(dcooks_influents.shape[0], "observations influentes.")
print(round(dcooks_influents.shape[0] / X_train_reg_lin.shape[0] * 100,2),"% du training set.")
# Out:
# 76 observations influentes.
# 7.42 % du training set.

# %% [markdown]
# #### Suppression des valeurs atypiques et influentes

# %% [markdown]
# Après avoir identifié les observations atypiques et influentes à partir des leviers, des résidus studentisés et des distances de Cook, la prochaine étape est de déterminer les index de ces observations pour pouvoir les supprimer de l'ensemble d'apprentissage.

# %%
# Obtenir les index à supprimer
index_a_supprimer = list(set(leviers_influents) & set(dcooks_influents)) + list(set(rstudents_influents) & set(dcooks_influents))
print(len(set(index_a_supprimer)),"observations atypiques et influentes supprimées.")

# Supprimer les valeurs de X_train_reg_lin
X_train_reg_lin = X_train_reg_lin.drop(index_a_supprimer, axis=0)
y_train_reg_lin = y_train_reg_lin.drop(index_a_supprimer, axis=0)

# Suppression des colonnes inutiles
X_train_reg_lin = X_train_reg_lin.drop(["obs", "levier", "rstudent", "dcooks"], axis=1)
# Out:
# 67 observations atypiques et influentes supprimées.

# %% [markdown]
# ### Ajustement du modèle

# %% [markdown]
# Nous pouvons maintenant effectuer une nouvelle régression linéaire multiple en utilisant les données nettoyées obtenues précédemment.

# %%
#Création d'un objet OLS et ajustement du modèle sur le training set
model_reg_lin = ols("margin_low ~ is_genuine+margin_up", data=X_train_reg_lin.join(y_train_reg_lin)).fit()
#Affichage des résultats de la régression
print(model_reg_lin.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     1038.
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):          4.32e-240
# Time:                        16:54:41   Log-Likelihood:                -317.87
# No. Observations:                 957   AIC:                             641.7
# Df Residuals:                     954   BIC:                             656.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.9467      0.211     28.180      0.000       5.533       6.361
# ...

# %% [markdown]
# La suppression des données atypiques et influentes a permis d'améliorer significativement notre modèle.
#
# Toutefois, l'analyse des conditions de la régression linéaire (à suivre) démontre à ce stade que nos données ne sont pas homoscédastiques et que par conséquent, la variance des résidus n'est pas constante.
#
# On applique donc une transformation logarithmique à la variable cible "y_train_reg_lin" pour améliorer cela.
#
# Ensuite, on ajuste à nouveau notre modèle sur le training set.

# %% [markdown]
# #### Transformation logarithmique de la variable cible

# %%
#Application de la transformation logarithmique
y_train_reg_lin_log = np.log(y_train_reg_lin)

#Création d'un objet OLS et ajustement du modèle sur le training set
model_reg_lin = ols("margin_low ~ is_genuine+margin_up", data=X_train_reg_lin.join(y_train_reg_lin_log)).fit()
#Affichage des résultats de la régression
print(model_reg_lin.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.667
# Method:                 Least Squares   F-statistic:                     959.9
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):          3.61e-229
# Time:                        16:54:41   Log-Likelihood:                 1115.2
# No. Observations:                 957   AIC:                            -2224.
# Df Residuals:                     954   BIC:                            -2210.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.8053      0.047     38.241      0.000       1.713       1.898
# ...

# %% [markdown]
# Le modèle linéaire avec transformation logarithmique de la variable dépendante a un R² de 0,668. Cela indique que ce modèle explique environ 66,8% de la variance de la variable dépendante. Il est légèrement inférieur après la transformation logarithmique de la variable dépendante mais il s'agit d'un transformation indispensable pour obtenir des résidus homoscédastiques.
#
# Tous les coefficients sont significativement différents de zéro avec une p-valeur inférieure à 0,001, ce qui suggère que ces coefficients sont statistiquement significatifs.

# %% [markdown]
# ### Validation du modèle

# %% [markdown]
# Afin de valider notre modèle, nous devons analyser les résultats de notre régression et vérifier que certaines hypothèses ci-dessous soient bien respectées:
#
# - **Hypothèse n° 1** : Relation linéaire entre la variable dépendantes et les variables indépendantes
# - **Hypothèse n° 2** : Normalité des résidus
# - **Hypothèse n° 3** : Pas de multicolinéarité entre les variables indépendantes
# - **Hypothèse n° 4** : Pas d'autocorrélation des résidus
# - **Hypothèse n° 5** : Homoscédasticité des résidus (variance constante)

# %% [markdown]
# #### Hypothèse 1: Relation linéaire entre la variable dépendantes et les variables indépendantes

# %% [markdown]
# Visualisons la linéarité pour nos deux variables explicatives:

# %%
# Création d'une figure avec deux sous-graphiques côte à côte
fig, axs = plt.subplots(ncols=2, figsize=(15, 5))

# Scatterplot de margin_up vs margin_low avec ligne de régression
sns.regplot(X_train_reg_lin["margin_up"], y_train_reg_lin_log, ax=axs[0],ci=None, line_kws={'color': 'red'})
axs[0].set(xlabel='Margin_up', ylabel='Margin_low')
axs[0].set_title('Relation linéaire entre margin_up et Margin_low',fontweight='bold')

# Scatterplot de is_genuine vs margin_low avec ligne de régression
sns.regplot(X_train_reg_lin["is_genuine"], y_train_reg_lin_log, ax=axs[1],ci=None, line_kws={'color': 'red'})
axs[1].set(xlabel='is_genuine', ylabel='Margin_low')
axs[1].set_title('Relation linéaire entre is_genuine et Margin_low',fontweight='bold')

plt.show()

# %% [markdown]
# La variable 'is_genuine' étant de type binaire, il était prévisible d'obtenir le résultat ci-dessus.

# %% [markdown]
# #### Hypothèse  2: Normalité des résidus

# %% [markdown]
# Nous allons procéder au test des hypothèses suivantes:
#
# - **Hypothèse nulle H0** : les données sont normalement distribuées
# - **Hypothèse alternative H1** : les données ne sont pas normalement distribuées
#
# Nous allons pour cela utiliser le test de Shapiro-Wilk.
# La statistique de test est calculée comme suit :
#
# - La statistique de test renvoie un nombre compris entre 0 et 1, où une valeur proche de 1 indique que les données sont proches d'une distribution normale.
#
# - La p-value indique la probabilité d'obtenir un résultat aussi extrême que celui observé dans les données si H0 est vraie. Si la p-value est inférieure au niveau de test (fixé à 0,05), on rejette H0.
#
# Commençons par effectuer une représentation graphique:

# %%
# Créer la figure avec deux sous-graphiques
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

# Tracer l'histogramme des résidus sur le premier sous-graphique
sns.histplot(model_reg_lin.resid, kde=True, ax=axes[0])
axes[0].set_xlabel('Valeurs résiduelles', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Nombre de résidus', fontsize=12, fontweight='bold')
axes[0].set_title('Histogramme des Résidus', fontsize=16, fontweight='bold')

# Tracer le Q-Q plot des résidus sur le deuxième sous-graphique
st.probplot(model_reg_lin.resid, plot=axes[1])
axes[1].set_title('Q-Q plot des résidus', fontsize=16, fontweight='bold')

# Afficher la figure
plt.show()

# %%
#Test de normalité des résidus
stat, p = shapiro(model_reg_lin.resid)

print("Résultat du test de normalité des résidus")
print('------------------------------------------')
print('Statistique de test :', stat)
print('p-value :', p)

if p<0.05:
    print("Rejet de l'hypothèse nulle H0")
else:
    print("L'hypothèse nulle H0 est acceptée")
# Out:
# Résultat du test de normalité des résidus
# ------------------------------------------
# Statistique de test : 0.9957319498062134
# p-value : 0.009415709413588047
# Rejet de l'hypothèse nulle H0

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Le test de normalité des résidus indique que la distribution des résidus n'est pas normale avec une p-value inférieure au niveau de significativité de 5%.
#
# Par conséquent, l'hypothèse nulle selon laquelle les résidus suivent une distribution normale est rejetée.
#
# Néanmoins, l'observation des résidus, le fait qu'ils ne soient pas très différents d'une distribution symétrique, et le fait que l'échantillon soit de taille suffisante permettent de dire que **les résultats obtenus par le modèle linéaire gaussien ne sont pas absurdes**, même si le résidu n'est pas considéré comme étant gaussien.
#
# </div>

# %% [markdown]
# #### Hypothèse 3: Pas de multicolinéarité entre les variables indépendantes

# %% [markdown]
# La multicollinéarité signifie que deux variables indépendantes ou plus sont fortement corrélées entre elles.
#
# Nous devons donc effectuer un test de colinéarité des variables de notre modèle. Pour cela, nous allons utiliser la fonction ` variance_inflation_factor`  de la bibliothèque ` statsmodels.stats.outliers_influence` .
#
# Pour chaque variable explicative du modèle, la fonction calcule le facteur d'inflation de la variance (VIF), qui mesure à quel point l'estimation de cette variable est affectée par la colinéarité avec les autres variables explicatives. Un VIF élevé indique que la variable est fortement corrélée avec les autres variables, ce qui peut rendre l'estimation instable et peu fiable.

# %%
#Test de colinéarité des variables
variables = model_reg_lin.model.exog
[variance_inflation_factor(variables, i) for i in np.arange(1,variables.shape[1])]
# Out:
# [1.634471047700393, 1.634471047700393]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Les coéfficients sont inférieurs à 10, il n'y a donc <b>pas de problème de colinéarité<b/>.
#
# </div>

# %% [markdown]
# #### Hypothèse 4: Pas d'autocorrélation des résidus

# %% [markdown]
# Nous allons ici utiliser le test de Durbin Watson qui est un test statistique utilisé pour détecter la présence d'autocorrélation dans les résidus d'une régression linéaire. En d'autres termes, il est utilisé pour déterminer si les erreurs d'une régression sont corrélées entre elles ou non.
#
# Le test de Durbin Watson calcule une statistique de test qui varie entre 0 et 4, où une valeur de 2 indique l'absence d'autocorrélation (les résidus ne sont pas corrélés entre eux) et des valeurs plus proches de 0 ou 4 indiquent une forte autocorrélation (les résidus sont très corrélés entre eux).

# %%
durbinWatson = durbin_watson(model_reg_lin.resid)
print('Durbin-Watson:', durbinWatson.round(2))
if durbinWatson < 1.5:
    print("Autocorrélation positive détectée")
elif durbinWatson > 2.5:
    print("Autocorrélation négative détectée")
else:
    print("Pas d'autocorrélation")
# Out:
# Durbin-Watson: 2.03
# Pas d'autocorrélation

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Le test de Durbin-Watson nous indique qu'il n'y a <b> pas d'autocorrélation significative des résidus</b>.
#
# </div>

# %% [markdown]
# #### Hypothèse 5 : Homoscédasticité des résidus

# %% [markdown]
# Ce test consiste à vérifier la constance de la variation des résidus. En cas d'hétéroscédasticité, la variance de l'erreur n'est pas constante. Dans le cas contraire, (hypothèse d'homoscédasticité) la variance de l'erreur est constante.
#
# Nous allons procéder au test des hypothèses suivantes:
#
# - **Hypothèse nulle H0** : Homoscédasticité
# - **Hypothèse alternative H1** : Hétéroscédasticité
#
# Nous allons pour cela utiliser le test de Breusch Pagan.

# %%
# Test de Breusch-Pagan
bp_test = het_breuschpagan(model_reg_lin.resid, model_reg_lin.model.exog)

# Affichage des résultats
print("Résultats du test de Breusch-Pagan")
print('------------------------------------------')
print("Statistique de test : ", bp_test[0])
print("p-value : ", bp_test[1])

if bp_test[1]<0.05:
    print("Rejet de l'hypothèse nulle H0")
else:
    print("L'hypothèse nulle H0 est acceptée")
# Out:
# Résultats du test de Breusch-Pagan
# ------------------------------------------
# Statistique de test :  0.5912729986367755
# p-value :  0.7440578444025318
# L'hypothèse nulle H0 est acceptée

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Le test montre une p-value de 0.74, ce qui indique que l'hypothèse nulle de l'homoscédasticité est acceptée. On peut donc conclure que la <b>variance des résidus est constante<b/>.
#
# </div>

# %%
# Graphique des résidus en fonction des observations
plt.figure(figsize=(12,6))
plt.scatter(X_train_reg_lin.index,model_reg_lin.resid)
plt.axhline(y=0, color='r', linestyle='-')
plt.title('Graphique des résidus en fonction des observations')
plt.xlabel('Observations')
plt.ylabel('Résidus')
plt.show()

# %% [markdown]
# ### Evaluation du Test set

# %%
# Faire des prédictions sur l'ensemble de test
y_pred_reg_lin = model_reg_lin.predict(X_test_reg_lin)
#Appliquer l'opération inverse de la transformation logarithmique sur les valeurs prédites
y_pred_reg_lin = np.exp(y_pred_reg_lin)

# Calculer le coefficient de détermination R²
r2 = r2_score(y_test_reg_lin, y_pred_reg_lin)

# Calculer l'erreur quadratique moyenne (MSE)
mse = mean_squared_error(y_test_reg_lin, y_pred_reg_lin)

# Afficher les résultats
print("R² sur l'ensemble de test : {:.2f}".format(r2))
print("MSE sur l'ensemble de test : {:.2f}".format(mse))
# Out:
# R² sur l'ensemble de test : 0.64
# MSE sur l'ensemble de test : 0.15

# %% [markdown]
# Le R² de 0.64 signifie que notre modèle explique 64% de la variation observée dans le test set. Cela indique une bonne adéquation du modèle aux données, mais il y a encore une proportion importante de la variation qui n'est pas expliquée.
#
# Le MSE (Mean Squared Error) qui mesure la qualité des prédictions du modèle est de 0.15. Il correspond à la moyenne des carrés des écarts entre les valeurs prédites et les valeurs observées. Une MSE de 0 indiquerait une prédiction parfaite. Dans notre cas, une MSE de 0.15 suggère que le modèle peut encore être amélioré, mais il fournit tout de même des prédictions raisonnables.

# %% [markdown]
# ### Prédictions des données manquantes à partir du modèle

# %% [markdown]
# Nous pouvons maintenant procéder aux prédictions sur nos 37 valeurs manquantes à partir de notre nouveau modèle.

# %%
#Prédiction des valeurs manquantes pour la variable 'margin_low'
predicted_values = model_reg_lin.predict(df_null[['is_genuine', 'margin_up']])
#Appliquer l'opération inverse de la transformation logarithmique sur les valeurs prédites
predicted_values = np.exp(predicted_values)

#Remplacement des valeurs manquantes par les valeurs prédites
df.loc[df['margin_low'].isnull(), 'margin_low'] = predicted_values
df["margin_low"] = df["margin_low"].round(2)
df.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %% [markdown]
# ## Régression logistique

# %% [markdown]
# ### Initialisation du modèle

# %%
#Conversion des données booléenes en format numérique
df['is_genuine'] = df['is_genuine'].astype(int)

#Création d'un training set et d'un test set
X = df[cols]
y = df["is_genuine"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("Taille du training set:", X_train.shape[0])
print("Taille du test set:", X_test.shape[0])

# Ajouter une constante aux données d'entraînement
X_train = sm.add_constant(X_train)
# Out:
# Taille du training set: 1050
# Taille du test set: 450

# %%
def train_logistic_regression(X_train, y_train, X_test, alpha=0.05, drop_non_significant=True):
    # Entraîner le modèle initial de régression logistique
    model = sm.Logit(y_train, X_train).fit()
    
    # Extraire les noms des variables explicatives
    variable_names = model.params.index[1:]
    
    # Calculer les p-values pour chaque variable explicative
    p_values = [model.wald_test(term) for term in variable_names]
    
    # Créer un tableau pour stocker les résultats du test de Wald
    wald_test_results = pd.DataFrame(index=variable_names, columns=['coef', 'std err', 'z', 'P>|z|', 'significant'])
    
    # Parcourir les variables et stocker les résultats du test de Wald dans le tableau
    for i, name in enumerate(variable_names):
        wald_test_results.loc[name, 'coef'] = model.params[i+1]
        wald_test_results.loc[name, 'std err'] = model.bse[i+1]
        wald_test_results.loc[name, 'z'] = model.tvalues[i+1]
        wald_test_results.loc[name, 'P>|z|'] = p_values[i].pvalue
        wald_test_results.loc[name, 'significant'] = (p_values[i].pvalue < alpha)
    print(wald_test_results)
    if drop_non_significant:
        # Obtenir les noms des variables non significatives
        non_significant_vars = wald_test_results[wald_test_results['significant'] == False].index
        
        # Supprimer les variables non significatives du DataFrame X_train
        X_train = X_train.drop(non_significant_vars, axis=1)
        X_test = X_test.drop(non_significant_vars, axis=1)
        
        # Entraîner à nouveau le modèle de régression logistique sur le nouveau DataFrame X_train
        model = sm.Logit(y_train, X_train).fit()
        
    # Retourner le modèle de régression logistique entraîné sur le DataFrame X_train modifié
    return model, X_train, X_test

# %%
#On lance la fonction
model_reg_log, X_train, X_test = train_logistic_regression(X_train, 
                                                           y_train, 
                                                           X_test, 
                                                           alpha=0.05, 
                                                           drop_non_significant=True)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.029984
#          Iterations 13
#                   coef   std err         z                   P>|z| significant
# diagonal     -0.514495  1.223061 -0.420662      0.6740021707555043       False
# height_left  -2.023325  1.382505 -1.463521     0.14332475838292685       False
# height_right -2.881016  1.171768 -2.458692    0.013944427364577894        True
# margin_low   -5.425069  1.044758 -5.192657   2.073139590356931e-07        True
# margin_up    -8.573082  2.216504 -3.867839  0.00010980420758866511        True
# length        5.557875  0.960936  5.783814   7.302577015718789e-09        True
# Optimization terminated successfully.
#          Current function value: 0.031101
#          Iterations 12

# %%
print(model_reg_log.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             is_genuine   No. Observations:                 1050
# Model:                          Logit   Df Residuals:                     1045
# Method:                           MLE   Df Model:                            4
# Date:                Fri, 24 Feb 2023   Pseudo R-squ.:                  0.9506
# Time:                        16:54:41   Log-Likelihood:                -32.656
# converged:                       True   LL-Null:                       -660.45
# Covariance Type:            nonrobust   LLR p-value:                1.410e-270
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -223.9345    151.594     -1.477      0.140    -521.053      73.184
# height_right    -3.3878      1.170     -2.896      0.004      -5.681      -1.095
# ...

# %% [markdown]
# ### Validation du modèle

# %% [markdown]
# Afin de valider notre modèle de régression logistique, il est important de vérifier que les hypothèses ci-dessous soient bien respectées:
#
# - **Hypothèse n° 1** : la variable de réponse est binaire
# - **Hypothèse n° 2** : les observations sont indépendantes
# - **Hypothèse n° 3** : Il n'y a pas de multicolinéarité entre les variables explicatives
# - **Hypothèse n° 4** : il n'y a pas de valeurs extrêmes aberrantes
# - **Hypothèse n° 5** : Il existe une relation linéaire entre les variables explicatives et le logit de la variable de réponse.
# - **Hypothèse n° 6** : la taille de l'échantillon est suffisamment grande

# %% [markdown]
# #### Hypothèse 1: La variable de réponse est binaire

# %%
# Hypothèse n°1: la variable de réponse est binaire
if len(y_train.unique()) != 2:
    print("La variable de réponse n'est pas binaire.")
else:
    print("La variable de réponse est binaire.")
# Out:
# La variable de réponse est binaire.

# %% [markdown]
# #### Hypothèse 2: Les observations sont indépendantes

# %%
# Hypothèse n°2: les observations sont indépendantes
if (X_train.index == y_train.index).all():
    print("Les observations sont indépendantes.")
else:
    print("Les observations ne sont pas indépendantes.")
# Out:
# Les observations sont indépendantes.

# %%
# Setup logistic regression model (using GLM method so that we can retrieve residuals)
logit_model = GLM(y_train, X_train, family=families.Binomial()).fit()

X_train_without_const = X_train.drop(columns="const")

# Create a list without 
list_index = X_train_without_const.index.tolist()
list_index.sort()

# Generate residual series plot
fig, axs = plt.subplots(nrows=3, figsize=(8,15))

# Residual Series Plot
axs[0].set_title("Residual Series Plot")
axs[0].set_xlabel("Index Number")
axs[0].set_ylabel("Deviance Residuals")
axs[0].plot(list_index, st.zscore(logit_model.resid_deviance).sort_index())
axs[0].axhline(y=0, ls="--", color='red')

# Residual Dependence Plot with Pearson residuals
axs[1].set_title("Residual Dependence Plot with Pearson residuals")
axs[1].set_xlabel("Fitted Values")
axs[1].set_ylabel("Pearson Residuals")
axs[1].scatter(logit_model.mu, st.zscore(logit_model.resid_deviance))
axs[1].plot([0.0, 1.0], [0.0, 0.0], "k-")

# Residual Dependence Plot with LOWESS smoothed residuals
axs[2].set_title("Residual Dependence Plot with LOWESS smoothed residuals")
axs[2].set_xlabel("Fitted Values")
axs[2].set_ylabel("Pearson Residuals")
axs[2].scatter(logit_model.mu, st.zscore(logit_model.resid_deviance))
y_hat_lowess = sm.nonparametric.lowess(logit_model.resid_deviance, logit_model.mu, 
                      return_sorted = False,
                      frac=2/3)
axs[2].scatter(logit_model.mu, y_hat_lowess)
axs[2].plot([0.0, 1.0], [0.0, 0.0], "k-")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Hypothèse  3: Pas de multicolinéarité entre les variables explicatives

# %%
# Hypothèse n°3: Il n'y a pas de multicolinéarité entre les variables explicatives.
# Nous allons utiliser le VIF (variance inflation factor) pour mesurer la collinéarité des variables explicatives.

# Calculer les VIF pour chaque variable explicative
vif = pd.DataFrame()
vif["Variables"] = X_train.columns
vif["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]

# Sélectionner les colonnes pertinentes à partir de la deuxième colonne de X_train
vif_sub = vif.iloc[1:]

# Vérifier si un VIF est supérieur à 10
if any(vif_sub["VIF"] > 10):
    print("Il y a une forte collinéarité entre les variables explicatives.")
    print(vif_sub[vif_sub["VIF"] > 10])
else:
    print(vif_sub[vif_sub["VIF"] < 10])
    print('------------------------------------------')
    print("Il n'y a pas de multicolinéarité entre les variables explicatives.")
# Out:
#       Variables       VIF
# 1  height_right  1.246390
# 2    margin_low  1.860570
# 3     margin_up  1.421997
# 4        length  2.168030
# ------------------------------------------
# Il n'y a pas de multicolinéarité entre les variables explicatives.

# %% [markdown]
# #### Hypothèse 4: Pas de valeurs extrêmes aberrantes

# %%
# Hypothèse n°4: il n'y a pas de valeurs extrêmes aberrantes
# Nous allons utiliser le test de Cook pour identifier les valeurs aberrantes potentielles.

# Get influence measures
influence = logit_model.get_influence()

# Obtain summary df of influence measures
summ_df = influence.summary_frame()

# Filter summary df to Cook distance
diagnosis_df = summ_df.loc[:,['cooks_d']]

# Append absolute standardized residual values
diagnosis_df['std_resid'] = st.zscore(logit_model.resid_pearson)
diagnosis_df['std_resid'] = diagnosis_df.loc[:,'std_resid'].apply(lambda x: np.abs(x))

# Sort by Cook's Distance
diagnosis_df.sort_values("cooks_d", ascending=False)
diagnosis_df
# Out:
#            cooks_d  std_resid
# 485   8.052061e-08   0.037579
# 527   1.309137e-11   0.020641
# 199   2.407187e-05   0.127839
# 889   2.066663e-10   0.022672
# 844   1.336471e-07   0.038974
# ...            ...        ...
# 1130  8.924959e-06   0.033293
# 1294  9.900910e-07   0.015238
# 860   1.771721e-07   0.043101
# 1459  1.549758e-14   0.018778
# 1126  4.361775e-10   0.015089
#
# [1050 rows x 2 columns]

# %%
# Set Cook's distance threshold
cook_threshold = 4 / len(X_train)
print(f"Threshold for Cook Distance = {cook_threshold}")
# Out:
# Threshold for Cook Distance = 0.0038095238095238095

# %%
# Plot influence measures (Cook's distance)
fig = influence.plot_index(y_var="cooks", threshold=cook_threshold)
plt.axhline(y=cook_threshold, ls="--", color='red')
fig.set_size_inches(12, 6)
fig.tight_layout(pad=2)

# %%
# Find number of observations that exceed Cook's distance threshold
outliers = diagnosis_df[diagnosis_df['cooks_d'] > cook_threshold]
prop_outliers = round(100*(len(outliers) / len(X_train)),1)
print(f'Proportion of data points that are highly influential = {prop_outliers}%')

# Find number of observations which are BOTH outlier (std dev > 3) and highly influential
extreme = diagnosis_df[(diagnosis_df['cooks_d'] > cook_threshold) & 
                       (diagnosis_df['std_resid'] > 3)]
prop_extreme = round(100*(len(extreme) / len(X_train)),1)
print(f'Proportion of highly influential outliers = {prop_extreme}%')
# Out:
# Proportion of data points that are highly influential = 1.7%
# Proportion of highly influential outliers = 0.3%

# %%
# Display top 5 most influential outliers
extreme.sort_values("cooks_d", ascending=False)
# Out:
#        cooks_d  std_resid
# 1122  0.313067  31.650620
# 728   0.168205   3.986227
# 1412  0.075465   3.062398

# %%
# Deep dive into index 1122 (extreme outlier)
X_train.loc[[1122,728,1412]]
# Out:
#       const  height_right  margin_low  margin_up  length
# 1122    1.0        104.17        4.15       3.40  113.85
# 728     1.0        104.16        4.08       3.35  111.76
# 1412    1.0        103.68        4.14       3.25  112.48

# %%
y_train.loc[[1122,728,1412]]
# Out:
# 1122    0
# 728     1
# 1412    0
# Name: is_genuine, dtype: int64

# %% [markdown]
# #### Hypothèse 5: Relation linéaire entre les variables explicatives et le logit de la variable de réponse

# %%
# Hypothèse n°5: Il existe une relation linéaire entre les variables explicatives et le logit de la variable de réponse.
# Nous allons utiliser le test de Box-Tidwell

X_train_lt = X_train.copy()  # lt = logit transform

# Define continuous variables
continuous_var = ['height_right', 'margin_low', 'margin_up', 'length']

# Add logit transform interaction terms (natural log) for continuous variables e.g. Age * Log(Age)
for var in continuous_var:
    X_train_lt[f'{var}:Log_{var}'] = X_train_lt[var].apply(lambda x: x * np.log(x)) #np.log = natural log

# Keep columns related to continuous variables
cols_to_keep = continuous_var + X_train_lt.columns.tolist()[-len(continuous_var):]

# Redefine independent variables to include interaction terms
X_lt = X_train_lt[cols_to_keep]
y_lt = y_train.copy()

# Add constant
X_lt_constant = sm.add_constant(X_lt, prepend=False)
  
# Build model and fit the data (using statsmodel's Logit)
logit_results = GLM(y_lt, X_lt_constant, family=families.Binomial()).fit()

# Display summary results
print(logit_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:             is_genuine   No. Observations:                 1050
# Model:                            GLM   Df Residuals:                     1041
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -29.585
# Date:                Fri, 24 Feb 2023   Deviance:                       59.170
# Time:                        16:54:42   Pearson chi2:                     355.
# No. Iterations:                    10
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
# Re-run logistic regression on original set of X and y variables
predicted = logit_model.predict(X_train)

# Get log odds values
log_odds = np.log(predicted / (1 - predicted))

# Visualize predictor continuous variable vs logit values
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))

# Plot for height_right vs log-odds
sns.regplot(x=X_train['height_right'].values, y=log_odds, ax=axs[0, 0], line_kws={'color': 'red'}, ci=None)
axs[0, 0].set_xlabel("height_right")
axs[0, 0].set_ylabel("Log-odds")

# Plot for margin_low vs log-odds
sns.regplot(x=X_train['margin_low'].values, y=log_odds, ax=axs[0, 1], line_kws={'color': 'red'}, ci=None)
axs[0, 1].set_xlabel("margin_low")
axs[0, 1].set_ylabel("Log-odds")

# Plot for margin_up vs log-odds
sns.regplot(x=X_train['margin_up'].values, y=log_odds, ax=axs[1, 0], line_kws={'color': 'red'}, ci=None)
axs[1, 0].set_xlabel("margin_up")
axs[1, 0].set_ylabel("Log-odds")

# Plot for length vs log-odds
sns.regplot(x=X_train['length'].values, y=log_odds, ax=axs[1, 1], line_kws={'color': 'red'}, ci=None)
axs[1, 1].set_xlabel("length")
axs[1, 1].set_ylabel("Log-odds")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Hypothèse 6: La taille de l'échantillon est suffisament grande

# %%
# Hypothèse n°6: la taille de l'échantillon est suffisamment grande
# Cette hypothèse est difficile à définir précisément, mais il est généralement recommandé d'avoir au moins 10 observations par variable explicative.
min_samples = 10 * len(X_train.columns[1:]) / y_train.value_counts().min()
if X_train.shape[0] >= min_samples:
    print("La taille de l'échantillon est suffisamment grande.")
else:
    print("La taille de l'échantillon est trop petite.")
# Out:
# La taille de l'échantillon est suffisamment grande.

# %% [markdown]
# ### Evaluation du modèle sur le Test Set

# %%
# Ajoutez une colonne de 1 pour la constante
X_test = sm.add_constant(X_test)
# Prédictions à partir du modèle sur le test set
y_pred_test = model_reg_log.predict(X_test)

# %%
# Tableau de seuils et d'auc correspondants
thresholds_table = []
roc_auc_scores = []

for threshold in np.arange(0, 1.1, 0.1):
    y_pred_test_class = [1 if x > threshold else 0 for x in y_pred_test]
    confusion_mat_test = confusion_matrix(y_test, y_pred_test_class)
    tn, fp, fn, tp = confusion_mat_test.ravel()
    specificity = tn / (tn + fp)
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)
    roc_auc_scores.append(roc_auc_score(y_test, y_pred_test_class))
    thresholds_table.append([threshold, roc_auc_scores[-1], specificity, sensitivity, accuracy])

# Trouver le seuil optimal à deux décimales
optimal_index = np.argmax([i[1] for i in thresholds_table])
optimal_threshold = thresholds_table[optimal_index][0]

# Afficher le tableau
print(tabulate(thresholds_table, headers=['Seuil', 'AUC', 'Spécificité', 'Sensibilité', 'Accuracy']))
# Afficher le seuil optimal
print("\n")
print('------------------------------------------')
print("Le seuil optimal est: {:.2f}".format(optimal_threshold))
# Out:
#   Seuil       AUC    Spécificité    Sensibilité    Accuracy
# -------  --------  -------------  -------------  ----------
#     0    0.5            0              1           0.642222
#     0.1  0.97205        0.944099       1           0.98
#     0.2  0.981366       0.962733       1           0.986667
#     0.3  0.981366       0.962733       1           0.986667
#     0.4  0.984472       0.968944       1           0.988889
#     0.5  0.987578       0.975155       1           0.991111
#     0.6  0.993434       0.993789       0.99308     0.993333
#     0.7  0.99654        1              0.99308     0.995556
#     0.8  0.991349       1              0.982699    0.988889
#     0.9  0.987889       1              0.975779    0.984444
#     1    0.5            1              0           0.357778
#
#
# ------------------------------------------
# Le seuil optimal est: 0.70

# %%
# Définition du seuil
threshold = 0.7
# Classification en fonction du seuil
y_pred_test_class = [1 if x > threshold else 0 for x in y_pred_test]

# %%
# Tracer la courbe ROC
fig, axs = plt.subplots(1, 2, figsize=(20, 6))

# Calcul de la courbe ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_test)
#roc_auc = auc(fpr, tpr)
# Calcul de l'AUC-ROC
auc_score = roc_auc_score(y_test, y_pred_test_class)


axs[0].plot(fpr, tpr, color='red', lw=3, label='Courbe ROC (AUC = %0.4f)' % auc_score)
axs[0].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
axs[0].set_xlim([-0.02, 1.0])
axs[0].set_ylim([0.0, 1.02])
axs[0].set_xlabel('Taux de faux positifs', fontsize=12, fontweight='bold')
axs[0].set_ylabel('Taux de vrais positifs', fontsize=12, fontweight='bold')
axs[0].set_title('Courbe ROC', fontsize=16, fontweight='bold')
axs[0].legend(loc="lower right")

# Afficher la matrice de confusion pour le seuil optimal
confusion_mat_test = confusion_matrix(y_test, y_pred_test_class)
sns.heatmap(confusion_mat_test,
            annot=True, 
            fmt='',
            xticklabels = ["False","True"],
            yticklabels=["False","True"],
            cmap='Blues',
            annot_kws={"size": 16, "weight": "bold"},
            ax=axs[1]
           )
axs[1].set_xlabel("Prédictions", fontsize=12, fontweight='bold')
axs[1].set_ylabel("Réalité", fontsize=12, fontweight='bold')
axs[1].set_title("Matrice de confusion", fontsize=16, fontweight='bold')

plt.show()


# Récupération des valeurs de la matrice de confusion
tn, fp, fn, tp = confusion_mat_test.ravel()
# Calcul de l'accuracy
accuracy = (tp + tn) / (tp + tn + fp + fn)
# Calcul de la sensibilité
sensibilite = tp / (tp + fn)
# Calcul de la spécificité
specificite = tn / (tn + fp)

print('------------------------------------------')
print("Accuracy :", accuracy.round(4))
print("Sensibilité :", sensibilite.round(4))
print("Spécificité :", specificite.round(4))
print("AUC :", auc_score.round(4))
# Out:
# ------------------------------------------
# Accuracy : 0.9956
# Sensibilité : 0.9931
# Spécificité : 1.0
# AUC : 0.9965

# %% [markdown]
# ## Prédictions via k-means

# %%
# Préparation du dataframe pour le k-means
X_kmeans = df.copy()
X_kmeans = df.iloc[:, 1:]

# %% [markdown]
# ### k-means

# %%
# Définir le nombre de clusters
n_clusters = 2

# Appliquer l'algorithme k-means
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(X_kmeans)

# Obtenir les étiquettes de cluster pour chaque observation
labels = kmeans.labels_
# Remplacer 0 par "Vrai" et 1 par "Faux"
labels = np.where(labels == 0, "Vrai", "Faux")

# Création d'une colonne "Cluster"
X_kmeans["Cluster"] = labels

# Vérification du nombre de vrais/faux
X_kmeans["Cluster"].value_counts()
# Out:
# Vrai    1017
# Faux     483
# Name: Cluster, dtype: int64

# %% [markdown]
# ### Evaluation du modèle k-means

# %%
# Matrice de confusion
confusion_matrix_kmeans = pd.crosstab(df['is_genuine'], X_kmeans['Cluster'])

# Heatmap
sns.heatmap(confusion_matrix_kmeans,
            annot=True, 
            fmt='',
            xticklabels=["False","True"],
            yticklabels=["False","True"],
            cmap='Blues',
            annot_kws={"size": 16, "weight": "bold"}
           )
plt.xlabel("Prédictions", fontsize=12, fontweight='bold')
plt.ylabel("Réalité", fontsize=12, fontweight='bold')
plt.title("Matrice de confusion", fontsize=16, fontweight='bold')
plt.show()


# Récupération des valeurs de la matrice de confusion kmeans
tn_kmeans, fp_kmeans, fn_kmeans, tp_kmeans = confusion_matrix_kmeans.values.ravel()

# Calcul de l'accuracy via kmeans
accuracy_kmeans = (tp_kmeans + tn_kmeans) / (tp_kmeans + tn_kmeans + fp_kmeans + fn_kmeans)
# Calcul de la sensibilité via kmeans
sensibilite_kmeans = tp_kmeans / (tp_kmeans + fn_kmeans)
# Calcul de la spécificité via kmeans
specificite_kmeans = tn_kmeans / (tn_kmeans + fp_kmeans)


print('------------------------------------------')
print("Accuracy :", accuracy_kmeans.round(4))
print("Sensibilité :", sensibilite_kmeans.round(4))
print("Spécificité :", specificite_kmeans.round(4))
# Out:
# ------------------------------------------
# Accuracy : 0.986
# Sensibilité : 0.998
# Spécificité : 0.962

# %% [markdown]
# ### ACP pour projection des individus

# %%
#On enregistre les clusters dans un df
X_cluster = X_kmeans["Cluster"].to_frame()
#On supprime la colonne "Cluster" en prévision de l'ACP
X_kmeans.drop(columns="Cluster",inplace=True)

# %%
#Choix du nombre de composantes
n_components = 6

pca = PCA(n_components=n_components)
pca.fit(X_kmeans)
# Out:
# PCA(n_components=6)

# %%
#Calcul de la variance cumulée
scree = (pca.explained_variance_ratio_*100).round(2)
scree_cum = scree.cumsum().round()
x_list = range(1, n_components+1)

#Représentation graphique
plt.figure(figsize=(10,3))
plt.bar(x_list, scree)
plt.plot(x_list, scree_cum,c="red",marker='o')
plt.xlabel("Rang de l'axe d'inertie")
plt.ylabel("Pourcentage d'inertie")
plt.title("Eboulis des valeurs propres")
plt.show(block=False)

# %%
#Calcul des coéfficients des variables pour chaque composante
pcs = pca.components_
#On met ces valeurs dans un df
pcs = pd.DataFrame(pcs)
#On rajoute les colonnes
pcs.columns = X_kmeans.columns
pcs.index = [f"PC{i}" for i in x_list]
#On transpose pour une meilleure visibilité
pcs = pcs.T

#Heatmap
sns.heatmap(pcs, cmap="YlGnBu",fmt='.2f',annot=True)
plt.xlabel("Composantes")
plt.ylabel("Variables")
plt.show()

# %%
#On se concentre ici uniquement sur le premier plan factoriel
x, y = 0,1

# %%
# Cercle des corrélations
fig, ax = plt.subplots(figsize=(10, 10))
for i in range(0, pca.components_.shape[1]):
    ax.arrow(0,
             0,  # Début de la flèche à l'origine
             pca.components_[x, i],  #0 pour PC1
             pca.components_[y, i],  #1 pour PC2
             head_width=0.07,
             head_length=0.07, 
             width=0.02,              )

    plt.text(pca.components_[x, i] + 0.05,
             pca.components_[y, i] + 0.05,
             X.columns[i])
    
# affichage des lignes horizontales et verticales
plt.plot([-1, 1], [0, 0], color='grey', ls='--')
plt.plot([0, 0], [-1, 1], color='grey', ls='--')


# nom des axes, avec le pourcentage d'inertie expliqué
plt.xlabel('PC{} ({}%)'.format(x+1, round(100*pca.explained_variance_ratio_[x],1)))
plt.ylabel('PC{} ({}%)'.format(y+1, round(100*pca.explained_variance_ratio_[y],1)))

# titre
plt.title("Cercle des corrélations (PC{} et PC{})".format(x+1, y+1), fontsize=16, fontweight="bold")

#ajout du cercle
plt.plot(np.cos(np.linspace(0, 2 * np.pi, 100)), np.sin(np.linspace(0, 2 * np.pi, 100)), linewidth=2)

plt.show()

# %%
#Projection des individus

#On calcule les coordonnées du nouvel espace
X_proj = pca.transform(X_kmeans)
#On rajoute la colonne "Cluster" à notre df pour afficher la visualisation des clusters
X_kmeans = X_kmeans.merge(X_cluster, how='inner', left_index=True, right_index=True)
# Obtenir les coordonnées des centroides
centroids = kmeans.cluster_centers_
# Calcul des coordonnées des centroides dans le nouvel espace
centroids_pca = pca.transform(centroids)


# Taille de la figure
plt.figure(figsize=(12,8))

#Affichage du nuage de points et centroides
sns.scatterplot(x=X_proj[:, x], y=X_proj[:, y], hue=X_kmeans['Cluster'],palette="YlGnBu")
sns.scatterplot(centroids_pca[:, 0], centroids_pca[:, 1], s=150, label='Centroïdes')

#Nom des axes avec le pourcentage d'inertie
plt.xlabel('PC{} ({}%)'.format(x+1, round(100*pca.explained_variance_ratio_[x],1)))
plt.ylabel('PC{} ({}%)'.format(y+1, round(100*pca.explained_variance_ratio_[y],1)))

# valeur x max et y max
x_max = np.abs(X_proj[:, x]).max() *1.1
y_max = np.abs(X_proj[:, y]).max() *1.1

#Affichage des lignes horizontales et verticales
plt.plot([-x_max, x_max], [0, 0], color='grey', alpha=0.5, ls='--')
plt.plot([0,0], [-y_max, y_max], color='grey', alpha=0.5, ls='--')

#On définit les limites de x et y 
plt.xlim(left= -x_max, right=x_max)
plt.ylim(bottom= -y_max, top=y_max)


#Titre du graphique
plt.title("Projection des individus (sur PC{} et PC{})".format(x+1, y+1),fontsize=16, fontweight="bold" )
plt.show()

# %% [markdown]
# ## Application des modèles sur données inconnues

# %%
data = pd.read_csv("Data/billets_production.csv")
data
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5

# %% [markdown]
# ### Par régression logistique

# %%
# Sélection des colonnes utilisées en vue de la prédictions
X_data = data[["height_right","margin_low","margin_up","length"]]
# Ajout d'une colonne de 1 pour la constante
X_data = sm.add_constant(X_data)

# Prédictions à partir du modèle sur le test set
y_pred_data = model_reg_log.predict(X_data)

#Définition du seuil
threshold = 0.7

# Classification selon le seuil défini précedemment
y_pred_data_class = [1 if x > threshold else 0 for x in y_pred_data]

#Vérification de chaque billet
print("Vérification des billets:")
print('------------------------------------------', "\n")

authentiques = [billet_id for prediction, billet_id in zip(y_pred_data_class, data["id"]) if prediction == 1]
contrefacons = [billet_id for prediction, billet_id in zip(y_pred_data_class, data["id"]) if prediction == 0]

if authentiques:
    print("Les billets authentiques sont :", authentiques)
else:
    print("Aucun billet authentique trouvé.")

if contrefacons:
    print("Les billets contrefaits sont :", contrefacons)
else:
    print("Aucun billet contrefait trouvé.")
# Out:
# Vérification des billets:
# ------------------------------------------
#
# Les billets authentiques sont : ['A_4', 'A_5']
# Les billets contrefaits sont : ['A_1', 'A_2', 'A_3']

# %% [markdown]
# ### Par K-Means

# %%
# Redéfinition du dataframe pour le kmeans
X_data_kmeans = data[["diagonal","height_left","height_right","margin_low","margin_up","length"]]

# Prédictions via kmeans
kmeans_prediction = kmeans.predict(X_data_kmeans)
kmeans_prediction = np.where(kmeans_prediction == 0, "Vrai", "Faux")

# Vérification de chaque billet
print("Vérification des billets:")
print('------------------------------------------', "\n")

authentiques = [billet_id for prediction, billet_id in zip(kmeans_prediction, data["id"]) if prediction == "Vrai"]
contrefacons = [billet_id for prediction, billet_id in zip(kmeans_prediction, data["id"]) if prediction == "Faux"]

if authentiques:
    print("Les billets authentiques sont :", authentiques)
else:
    print("Aucun billet authentique trouvé.")

if contrefacons:
    print("Les billets contrefaits sont :", contrefacons)
else:
    print("Aucun billet contrefait trouvé.")
# Out:
# Vérification des billets:
# ------------------------------------------
#
# Les billets authentiques sont : ['A_4', 'A_5']
# Les billets contrefaits sont : ['A_1', 'A_2', 'A_3']
